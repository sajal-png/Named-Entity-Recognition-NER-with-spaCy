# %% [markdown]
# # Named Entity Recognition (NER) with spaCy
#
# In this notebook, I have implemented a Named Entity Recognition (NER) model using spaCy.I have used the pre-trained spaCy model for English and demonstrated how to process text and extract named entities.
#
# ## 1. Installation and Setup
#
# First, ensure you have spaCy installed and the English model downloaded. Run the following commands in your Jupyter Notebook:

# %%
# %pip install spacy textblob
# Out:
# Requirement already satisfied: spacy in c:\python311\lib\site-packages (3.7.5)
# Requirement already satisfied: textblob in c:\python311\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\python311\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\python311\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\python311\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\python311\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\python311\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\python311\lib\site-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\python311\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\python311\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\python311\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\python311\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\python311\lib\site-packages (from spacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from spacy) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\python311\lib\site-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\python311\lib\site-packages (from spacy) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\python311\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: nltk>=3.8 in c:\python311\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: language-data>=1.2 in c:\python311\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: click in c:\python311\lib\site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\python311\lib\site-packages (from nltk>=3.8->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\python311\lib\site-packages (from nltk>=3.8->textblob) (2024.5.15)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in c:\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\python311\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\python311\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\python311\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\python311\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\python311\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in c:\python311\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in c:\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      --------------------------------------- 12.8/12.8 MB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\python311\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.8.2)
# Requirement already satisfied: jinja2 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: language-data>=1.2 in c:\python311\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: colorama in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\python311\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\python311\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sajalpatel\appdata\roaming\python\python311\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\python311\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\python311\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\python311\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in c:\python311\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in c:\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip available: 22.3.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy
from spacy import displacy
from textblob import TextBlob

# %%
# Loading pre-trained spaCy model
nlp = spacy.load("en_core_web_sm")

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
# Sample text
text = "Elon Musk is looking to buy Twitter .Tim Cook is the CEO of Apple. Apple is looking at buying U.K. startup for $1 billion.  Amazon, founded by Jeff Bezos in 1994, announced a partnership with Microsoft to enhance cloud computing services. The collaboration aims to compete with Google's Cloud platform. Meanwhile, Tesla's CEO Elon Musk tweeted about launching a new electric truck in 2025. In Europe, the European Central Bank (ECB) is considering digital euro adoption, which could impact the cryptocurrency market significantly. Additionally, the new series of the popular Netflix show 'Stranger Things' is set to release next month, sparking excitement among fans worldwide. In sports, Serena Williams announced her retirement after the US Open, a tournament she has won six times. The COVID-19 pandemic continues to affect global markets, with companies like Pfizer and Moderna are working on updated vaccines. In Asia, Alibaba's shares surged after a record-breaking Singles' Day sales event, generating over $30 billion in revenue. At the same time, climate activists in Australia are protesting against the Adani coal mine project, citing environmental concerns."

# Processing the text with spaCy pipeline
doc = nlp(text)

# %%
# Extracting and displaying named entities
for ent in doc.ents:
    print(f"Entity: {ent.text}, Label: {ent.label_}")
# Out:
# Entity: Elon Musk, Label: PERSON
# Entity: Cook, Label: PERSON
# Entity: Apple, Label: ORG
# Entity: Apple, Label: ORG
# Entity: U.K., Label: GPE
# Entity: $1 billion, Label: MONEY
# Entity: Amazon, Label: ORG
# Entity: Jeff Bezos, Label: PERSON
# Entity: 1994, Label: DATE
# Entity: Microsoft, Label: ORG
# Entity: Google, Label: ORG
# Entity: Tesla, Label: ORG
# Entity: Elon Musk, Label: PERSON
# Entity: 2025, Label: DATE
# Entity: Europe, Label: LOC
# Entity: the European Central Bank, Label: ORG
# Entity: Netflix, Label: ORG
# Entity: Stranger Things', Label: WORK_OF_ART
# Entity: next month, Label: DATE
# Entity: Serena Williams, Label: PERSON
# Entity: the US Open, Label: EVENT
# Entity: six, Label: CARDINAL
# Entity: COVID-19, Label: ORG
# Entity: Pfizer, Label: ORG
# Entity: Moderna, Label: PERSON
# Entity: Asia, Label: LOC
# Entity: Alibaba, Label: GPE
# Entity: over $30 billion, Label: MONEY
# Entity: Australia, Label: GPE
# Entity: Adani, Label: ORG

# %%
# Visualize
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is looking to buy Twitter .Tim
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is the CEO of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is looking at buying
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  startup for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , founded by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jeff Bezos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1994
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , announced a partnership with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to enhance cloud computing services. The collaboration aims to compete with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's Cloud platform. Meanwhile,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  tweeted about launching a new electric truck in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2025
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . In
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the European Central Bank
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (ECB) is considering digital euro adoption, which could impact the cryptocurrency market significantly. Additionally, the new series of the popular
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Netflix
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  show '
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stranger Things'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  is set to release
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     next month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , sparking excitement among fans worldwide. In sports,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Serena Williams
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  announced her retirement after
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the US Open
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# , a tournament she has won
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  times. The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  pandemic continues to affect global markets, with companies like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pfizer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-ali

# %% [markdown]
# # Part-of-Speech (POS) Tagging

# %%
print("Part-of-Speech Tags:")
for token in doc:
    print(f"Token: {token.text}, POS: {token.pos_}, Tag: {token.tag_}")
# Out:
# Part-of-Speech Tags:
# Token: Elon, POS: PROPN, Tag: NNP
# Token: Musk, POS: PROPN, Tag: NNP
# Token: is, POS: AUX, Tag: VBZ
# Token: looking, POS: VERB, Tag: VBG
# Token: to, POS: PART, Tag: TO
# Token: buy, POS: VERB, Tag: VB
# Token: Twitter, POS: PROPN, Tag: NNP
# Token: .Tim, POS: PUNCT, Tag: .
# Token: Cook, POS: PROPN, Tag: NNP
# Token: is, POS: AUX, Tag: VBZ
# Token: the, POS: DET, Tag: DT
# Token: CEO, POS: NOUN, Tag: NN
# Token: of, POS: ADP, Tag: IN
# Token: Apple, POS: PROPN, Tag: NNP
# Token: ., POS: PUNCT, Tag: .
# Token: Apple, POS: PROPN, Tag: NNP
# Token: is, POS: AUX, Tag: VBZ
# Token: looking, POS: VERB, Tag: VBG
# Token: at, POS: ADP, Tag: IN
# Token: buying, POS: VERB, Tag: VBG
# Token: U.K., POS: PROPN, Tag: NNP
# Token: startup, POS: NOUN, Tag: NN
# Token: for, POS: ADP, Tag: IN
# Token: $, POS: SYM, Tag: $
# Token: 1, POS: NUM, Tag: CD
# Token: billion, POS: NUM, Tag: CD
# Token: ., POS: PUNCT, Tag: .
# Token:  , POS: SPACE, Tag: _SP
# Token: Amazon, POS: PROPN, Tag: NNP
# Token: ,, POS: PUNCT, Tag: ,
# Token: founded, POS: VERB, Tag: VBN
# Token: by, POS: ADP, Tag: IN
# Token: Jeff, POS: PROPN, Tag: NNP
# Token: Bezos, POS: PROPN, Tag: NNP
# Token: in, POS: ADP, Tag: IN
# Token: 1994, POS: NUM, Tag: CD
# Token: ,, POS: PUNCT, Tag: ,
# Token: announced, POS: VERB, Tag: VBD
# Token: a, POS: DET, Tag: DT
# Token: partnership, POS: NOUN, Tag: NN
# Token: with, POS: ADP, Tag: IN
# Token: Microsoft, POS: PROPN, Tag: NNP
# Token: to, POS: PART, Tag: TO
# Token: enhance, POS: VERB, Tag: VB
# Token: cloud, POS: NOUN, Tag: NN
# Token: computing, POS: NOUN, Tag: NN
# Token: services, POS: NOUN, Tag: NNS
# Token: ., POS: PUNCT, Tag: .
# Token: The, POS: DET, Tag: DT
# Token: collaboration, POS: NOUN, Tag: NN
# Token: aims, POS: VERB, Tag: VBZ
# Token: to, POS: PART, Tag: TO
# Token: compete, POS: VERB, Tag: VB
# Token: with, POS: ADP, Tag: IN
# Token: Google, POS: PROPN, Tag: NNP
# Token: 's, POS: PART, Tag: POS
# Token: Cloud, POS: PROPN, Tag: NNP
# Token: platform, POS: NOUN, Tag: NN
# Token: ., POS: PUNCT, Tag: .
# Token: Meanwhile, POS: ADV, Tag: RB
# Token: ,, POS: PUNCT, Tag: ,
# Token: Tesla, POS: PROPN, Tag: NNP
# Token: 's, POS: PART, Tag: POS
# Token: CEO, POS: NOUN, Tag: NN
# Token: Elon, POS: PROPN, Tag: NNP
# Token: Musk, POS: PROPN, Tag: NNP
# Token: tweeted, POS: VERB, Tag: VBD
# Token: about, POS: ADP, Tag: IN
# Token: launching, POS: VERB, Tag: VBG
# Token: a, POS: DET, Tag: DT
# Token: new, POS: ADJ, Tag: JJ
# Token: electric, POS: ADJ, Tag: JJ
# Token: truck, POS: NOUN, Tag: NN
# Token: in, POS: ADP, Tag: IN
# Token: 2025, POS: NUM, Tag: CD
# Token: ., POS: PUNCT, Tag: .
# Token: In, POS: ADP, Tag: IN
# Token: Europe, POS: PROPN, Tag: NNP
# Token: ,, POS: PUNCT, Tag: ,
# Token: the, POS: DET, Tag: DT
# Token: European, POS: PROPN, Tag: NNP
# Token: Central, POS: PROPN, Tag: NNP
# Token: Bank, POS: PROPN, Tag: NNP
# Token: (, POS: PUNCT, Tag: -LRB-
# Token: ECB, POS: PROPN, Tag: NNP
# Token: ), POS: PUNCT, Tag: -RRB-
# Token: is, POS: AUX, Tag: VBZ
# Token: considering, POS: VERB, Tag: VBG
# Token: digital, POS: ADJ, Tag: JJ
# Token: euro, POS: NOUN, Tag: NN
# Token: adoption, POS: NOUN, Tag: NN
# Token: ,, POS: PUNCT, Tag: ,
# Token: which, POS: PRON, Tag: WDT
# Token: could, POS: AUX, Tag: MD
# Token: impact, POS: VERB, Tag: VB
# Token: the, POS: DET, Tag: DT
# Token: cryptocurrency, POS: NOUN, Tag: NN
# Token: market, POS: NOUN, Tag: NN
# Token: significantly, POS: ADV, Tag: RB
# Token: ., POS: PUNCT, Tag: .
# Token: Additionally, POS: ADV, Tag: RB
# Token: ,, POS: PUNCT, Tag: ,
# Token: the, POS: DET, Tag: DT
# Token: new, POS: ADJ, Tag: JJ
# Token: series, POS: NOUN, Tag: NN
# Token: of, POS: ADP, Tag: IN
# Token: the, POS: DET, Tag: DT
# Token: popular, POS: ADJ, Tag: JJ
# Token: Netflix, POS: PROPN, Tag: NNP
# Token: show, POS: NOUN, Tag: NN
# Token: ', POS: PUNCT, Tag: ``
# Token: Stranger, POS: PROPN, Tag: NNP
# Token: Things, POS: NOUN, Tag: NNS
# Token: ', POS: PUNCT, Tag: ''
# Token: is, POS: AUX, Tag: VBZ
# Token: set, POS: VERB, Tag: VBN
# Token: to, POS: PART, Tag: TO
# Token: release, POS: VERB, Tag: VB
# Token: next, POS: ADJ, Tag: JJ
# Token: month, POS: NOUN, Tag: NN
# Token: ,, POS: PUNCT, Tag: ,
# Token: sparking, POS: VERB, Tag: VBG
# Token: excitement, POS: NOUN, Tag: NN
# Token: among, POS: ADP, Tag: IN
# Token: fans, POS: NOUN, Tag: NNS
# Token: worldwide, POS: ADV, Tag: RB
# Token: ., POS: PUNCT, Tag: .
# Token: In, POS: ADP, Tag: IN
# Token: sports, POS: NOUN, Tag: NNS
# Token: ,, POS: PUNCT, Tag: ,
# Token: Serena, POS: PROPN, Tag: NNP
# Token: Williams, POS: PROPN, Tag: NNP
# Token: announced, POS: VERB, Tag: VBD
# Token: her, POS: PRON, Tag: PRP$
# Token: retirement, POS: NOUN, Tag: NN
# Token: after, POS: ADP, Tag: IN
# Token: the, POS: DET, Tag: DT
# Token: US, POS: PROPN, Tag: NNP
# Token: Open, POS: PROPN, Tag: NNP
# Token: ,, POS: PUNCT, Tag: ,
# Token: a, POS: DET, Tag: DT
# Token: tournament, POS: NOUN, Tag: NN
# Token: she, POS: PRON, Tag: PRP
# Token: has, POS: AUX, Tag: VBZ
# Token: won, POS: VERB, Tag: VBN
# Token: six, POS: NUM, Tag: CD
# Token: times, POS: NOUN, Tag: NNS
# Token: ., POS: PUNCT, Tag: .
# Token: The, POS: DET, Tag: DT
# Token: COVID-19, POS: NOUN, Tag: NN
# Token: pandemic, POS: NOUN, Tag: NN
# Token: continues, POS: VERB, Tag: VBZ
# Token: to, POS: PART, Tag: TO
# Token: affect, POS: VERB, Tag: VB
# Token: global, POS: ADJ, Tag: JJ
# Token: markets, POS: NOUN, Tag: NNS
# Token: ,, POS: PUNCT, Tag: ,
# Token: with, POS: SCONJ, Tag: IN
# Token: companies, POS: NOUN, Tag: NNS
# Token: like, POS: ADP, Tag: IN
# Token: Pfizer, POS: PROPN, Tag: NNP
# Token: and, POS: CCONJ, Tag: CC
# Token: Moderna, POS: PROPN, Tag: NNP
# Token: are, POS: AUX, Tag: VBP
# Token: working, POS: VERB, Tag: VBG
# Token: on, POS: ADP, Tag: IN
# Token: updated, POS: VERB, Tag: VBN
# Token: vaccines, POS: NOUN, Tag: NNS
# Token: ., POS: PUNCT, Tag: .
# Token: In, POS: ADP, Tag: IN
# Token: Asia, POS: PROPN, Tag: NNP
# Token: ,, POS: PUNCT, Tag: ,
# Token: Alibaba, POS: PROPN, Tag: NNP
# Token: 's, POS: PART, Tag: POS
# Token: shares, POS: NOUN, Tag: NNS
# Token: surged, POS: VERB, Tag: VBD
# Token: after, POS: ADP, Tag: IN
# Token: a, POS: DET, Tag: DT
# Token: record, POS: NOUN, Tag: NN
# Token: -, POS: PUNCT, Tag: HYPH
# Token: breaking, POS: VERB, Tag: VBG
# Token: Singles, POS: PROPN, Tag: NNP
# Token: ', POS: PART, Tag: POS
# Token: Day, POS: NOUN, Tag: NN
# Token: sales, POS: NOUN, Tag: NNS
# Token: event, POS: NOUN, Tag: NN
# Token: ,, POS: PUNCT, Tag: ,
# Token: generating, POS: VERB, Tag: VBG
# Token: over, POS: ADP, Tag: IN
# Token: $, POS: SYM, Tag: $
# Token: 30, POS: NUM, Tag: CD
# Token: billion, POS: NUM, Tag: CD
# Token: in, POS: ADP, Tag: IN
# Token: revenue, POS: NOUN, Tag: NN
# Token: ., POS: PUNCT, Tag: .
# Token: At, POS: ADP, Tag: IN
# Token: the, POS: DET, Tag: DT
# Token: same, POS: ADJ, Tag: JJ
# Token: time, POS: NOUN, Tag: NN
# Token: ,, POS: PUNCT, Tag: ,
# Token: climate, POS: NOUN, Tag: NN
# Token: activists, POS: NOUN, Tag: NNS
# Token: in, POS: ADP, Tag: IN
# Token: Australia, POS: PROPN, Tag: NNP
# Token: are, POS: AUX, Tag: VBP
# Token: protesting, POS: VERB, Tag: VBG
# Token: against, POS: ADP, Tag: IN
# Token: the, POS: DET, Tag: DT
# Token: Adani, POS: PROPN, Tag: NNP
# Token: coal, POS: NOUN, Tag: NN
# Token: mine, POS: NOUN, Tag: NN
# Token: project, POS: NOUN, Tag: NN
# Token: ,, POS: PUNCT, Tag: ,
# Token: citing, POS: VERB, Tag: VBG
# Token: environmental, POS: ADJ, Tag: JJ
# Token: concerns, POS: NOUN, Tag: NNS
# Token: ., POS: PUNCT, Tag: .

# %% [markdown]
# # Sentiment Analysis

# %%
text1 = "I love programming in Python. It's such a versatile language!"

blob = TextBlob(text1)
sentiment = blob.sentiment

print("Sentiment Analysis:")
print(f"Polarity: {sentiment.polarity}")
print(f"Subjectivity: {sentiment.subjectivity}")
# Out:
# Sentiment Analysis:
# Polarity: 0.25
# Subjectivity: 0.55
